# %%
import requests
import json

# Import the API key
from api_keys import asteroid_key

# %%
target_url = f"https://api.nasa.gov/neo/rest/v1/neo/browse?api_key={asteroid_key}"

# %%
aster_data = requests.get(target_url).json()

aster_data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/neo/browse?page=1&size=20&api_key=PgfVUQIaMasp8gCG0pqk8vgtOZRNuzHQlr3boNGX',
#   'self': 'http://api.nasa.gov/neo/rest/v1/neo/browse?page=0&size=20&api_key=PgfVUQIaMasp8gCG0pqk8vgtOZRNuzHQlr3boNGX'},
#  'page': {'size': 20,
#   'total_elements': 31425,
#   'total_pages': 1572,
#   'number': 0},
#  'near_earth_objects': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2000433?api_key=PgfVUQIaMasp8gCG0pqk8vgtOZRNuzHQlr3boNGX'},
#    'id': '2000433',
#    'neo_reference_id': '2000433',
#    'name': '433 Eros (A898 PA)',
#    'name_limited': 'Eros',
#    'designation': '433',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433',
#    'absolute_magnitude_h': 10.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 23.0438466577,
#      'estimated_diameter_max': 51.5276075896},
#     'meters': {'estimated_diameter_min': 23043.8466576534,
#      'estimated_diameter_max': 51527.6075895943},
# ...

# %%
# Print to logger
print("Beginning Asteroid Data Retrieval     ")
print("-----------------------------")

#Retrieviving basic Asteroid data Designated Name, Name(short), Estimated Diameter (min & max), Relative velocity, Closest approach date
#make toggles for the visual
try :   
    designation =
    name = 
    est_diameter_min = 
    est_diameter_max = 
    rel_vel = 
    nxt_close_approach_date = 
    miss_distance = 
    haz = 
    orbit =
